# %% [markdown]
# # Extraction de candidats en fonctions des coordonnées de l'_Encyclopédie_
#
# Petit programme montrant comment extraire de Wikidata des lieux proches d'un point donné par ses coordonnées géographiques dans l'_Encyclopédie_.
#
# Auteur : Pierre Nugues

# %%
import json
from tqdm import tqdm
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import statistics
import regex as re
import plotly.graph_objects as go
import plotly.express as px
import regex as re
import bs4
import requests
from geopy import distance

# %% [markdown]
# ## Le jeu de données et l'extraction des coordonnées du texte
# On utilise des données où on a extrait les coordonnées gégraphiques de wikidata au préalable

# %%
with open('diderot_1751_wd_extraction.json', 'r') as f:
    diderot_wd = json.loads(f.read())

# %% [markdown]
# Un exemple

# %%
diderot_wd[7675]
# Out:
# {'vedette': 'MOLINA',
#  'entreeid': 'v10-1676-0',
#  'texte': 'MOLINA, (Géog.)\u200b ville d’Espagne, dans la nouvelle Castille, sur le Gallo, à 3 lieues des frontieres de l’Arragon, près de Caracena. Cette ville est dans un pays de pâturage, où l’on nourrit des brebis qui portent une laine précieuse. Elle est située à 10 lieues S. E. de Siguenza, 28 N. E. de Madrid. Long. 15. 55. lat. 40. 50. (D. J.)\u200b',
#  'qid': ['Q919050'],
#  'wd_statements': [{'desc_en': ['municipality of Spain'],
#    'desc_fr': ['commune espagnole'],
#    'libellé_en': ['Molina de Aragón'],
#    'libellé_fr': ["Molina d'Aragon"],
#    'type': ['Q2074737'],
#    'geo': ['Point(-1.888611111 40.843888888)']}]}

# %% [markdown]
# Les expressions régulières

# %%
lat_long = r'(latitude|latit\.?|lat\.?|longitude|longit\.?|long\.?|lon\.?)'
lat_long
# Out:
# '(latitude|latit\\.?|lat\\.?|longitude|longit\\.?|long\\.?|lon\\.?)'

# %%
coord = r'((?:\p{N}+\.\s*)+)' # On ne capture que la plus longue chaîne

# %%
expr = (lat_long) + r'\s*' + coord
expr
# Out:
# '(latitude|latit\\.?|lat\\.?|longitude|longit\\.?|long\\.?|lon\\.?)\\s*((?:\\p{N}+\\.\\s*)+)'

# %% [markdown]
# L'extraction et la normalisation avec le méridien de l'île de Fer

# %%
long_ile_de_fer = 17 + 39 / 60 + 46 / 3600
long_ile_de_fer
# Out:
# 17.662777777777777

# %%
def convertit_coord(coords: list[tuple], long_ile_de_fer=17.662777777777777):
    """
    Convertit une liste de deux éléments du type
    [('long.', '26. 57. '), ('lat.', '47. 55.')]
    en un couple de coordonnées avec Greenwich comme méridien de référence
    (47.916666666666664, 9.287222222222223)
    """
    latitude = 0
    longitude = 0
    for coord in coords:
        coord_dec = 0
        chiffres = coord[1].strip().split()
        nouv_chiffres = []
        for chiffre in chiffres:
            chiffre = chiffre.strip()
            if chiffre[-1] == '.':
                chiffre = chiffre[:-1]
            if chiffre is int:
                chiffre = int(chiffre)
                nouv_chiffres += [chiffre]
            else:
                nouv_chiffres += map(lambda x: int(x.strip()), chiffre.split('.'))

        for i, chiffre in enumerate(nouv_chiffres):
            coord_dec += chiffre/(60**i)
        if re.match('lon', coord[0].lower()):
            longitude = coord_dec - long_ile_de_fer
        elif re.match('lat', coord[0].lower()):
            latitude = coord_dec
        else:
            return False
    return (latitude, longitude)

# %%
def extrait_coord_txt(expr, texte):
    m = re.findall(expr, texte.strip().lower())
    if m and len(m) == 2:
        return m
    else:
        return False

# %%
def extrait_coord_format_wd(article):
    if 'wd_statements' in article and 'geo' in article['wd_statements'][0]:
            coords_wd = article['wd_statements'][0]['geo'][0]
            [long_wd, lat_wd] = re.findall(r'-?\p{N}+\.-?\p{N}+', coords_wd)
            return (float(lat_wd), float(long_wd))
    else:
          return False

# %% [markdown]
# Le calcul de la distance entre les coordonnées Wikidata et les coordonnées de l'_Encyclopédie_

# %%
cnt = 0
for i, article in enumerate(diderot_wd[7675:7676]):
    #if 'qid' in article:
    #    continue
    coord_txt = extrait_coord_txt(expr, article['texte'])
    if coord_txt:
        coord_encyclo = convertit_coord(coord_txt)
    else:
        continue
    print('Article :', article)
    print('Coordonnées extraites :', coord_txt)
    print('Coordonnées normalisées :', coord_encyclo)
    coords_wd = extrait_coord_format_wd(article)
    print('Coordonnées wikidata :', coords_wd)
    if coord_encyclo and coords_wd:
        dist = distance.geodesic(coords_wd, coord_encyclo).km
        cnt += 1
        print('Distance :', dist)
cnt
# Out:
# Article : {'vedette': 'MOLINA', 'entreeid': 'v10-1676-0', 'texte': 'MOLINA, (Géog.)\u200b ville d’Espagne, dans la nouvelle Castille, sur le Gallo, à 3 lieues des frontieres de l’Arragon, près de Caracena. Cette ville est dans un pays de pâturage, où l’on nourrit des brebis qui portent une laine précieuse. Elle est située à 10 lieues S. E. de Siguenza, 28 N. E. de Madrid. Long. 15. 55. lat. 40. 50. (D. J.)\u200b', 'qid': ['Q919050'], 'wd_statements': [{'desc_en': ['municipality of Spain'], 'desc_fr': ['commune espagnole'], 'libellé_en': ['Molina de Aragón'], 'libellé_fr': ["Molina d'Aragon"], 'type': ['Q2074737'], 'geo': ['Point(-1.888611111 40.843888888)']}]}
# Coordonnées extraites : [('long.', '15. 55. '), ('lat.', '40. 50. ')]
# Coordonnées normalisées : (40.833333333333336, -1.7461111111111105)
# Coordonnées wikidata : (40.843888888, -1.888611111)
# Distance : 12.075488278906363
# 1

# %% [markdown]
# ## Construction de requêtes d'extraction
# On construit une requête et l'on l'applique. On voit qu'on doit nettoyer les données récupérées.

# %%
url = 'https://query.wikidata.org/bigdata/namespace/wdq/sparql'

# %%
prefixes = '''PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX p: <http://www.wikidata.org/prop/>
PREFIX ps: <http://www.wikidata.org/prop/statement/>'''

# %%
headers = {
    'User-Agent': 'NLP-project/1.0 (pierre.nugues@cs.lth.se)'
}

# %%
def applique_requete(qt, prefixes, headers):
    try:
        data = requests.get(
            url, params={
                'query': prefixes + qt, 
                'format': 'json', 
                'headers': headers}).json()
        data = data['results']['bindings']
    except:
        data = ['échec']
    return data

# %% [markdown]
# La requête reprise de stackoverflow :
# `https://stackoverflow.com/questions/49302399/how-to-get-cities-around-a-location-in-wikidata`

# %%
def cree_req_coord(coord):
    query_dist = """SELECT DISTINCT ?distance ?qid ?qidLabel ?coords WHERE {{

   # Use the around service
   SERVICE wikibase:around {{ 
     # Looking for items with coordinate locations(P625)
     # ?qid wdt:P625 ?coords . 
     
     # That are in a circle with a centre of with a point
     bd:serviceParam wikibase:center "{0}"^^geo:wktLiteral   . 
     # Where the circle has a radius of 20km
     bd:serviceParam wikibase:radius "20" . 
     bd:serviceParam wikibase:distance ?distance .
   }} .

   # ?qid wdt:P31/wdt:P279* wd:Q486972.

   # Use the label service to get the English label
   SERVICE wikibase:label {{
   bd:serviceParam wikibase:language "en" . 
   }}
}}
ORDER BY ?distance""".format(coord)
    return query_dist

# %%
req = cree_req_coord('Point(-6.50,39.1)')
req
# Out:
# 'SELECT DISTINCT ?distance ?qid ?qidLabel ?coords WHERE {\n\n   # Use the around service\n   SERVICE wikibase:around { \n     # Looking for items with coordinate locations(P625)\n     ?qid wdt:P625 ?coords . \n     \n     # That are in a circle with a centre of with a point\n     bd:serviceParam wikibase:center "Point(-6.50,39.1)"^^geo:wktLiteral   . \n     # Where the circle has a radius of 20km\n     bd:serviceParam wikibase:radius "20" . \n     bd:serviceParam wikibase:distance ?distance .\n   } .\n\n   ?qid wdt:P31/wdt:P279* wd:Q486972.\n\n   # Use the label service to get the English label\n   SERVICE wikibase:label {\n   bd:serviceParam wikibase:language "en" . \n   }\n}\nORDER BY ?distance'

# %%
req = cree_req_coord('Point(3.43,50.45)')
req
# Out:
# 'SELECT DISTINCT ?distance ?qid ?qidLabel ?coords WHERE {\n\n   # Use the around service\n   SERVICE wikibase:around { \n     # Looking for items with coordinate locations(P625)\n     ?qid wdt:P625 ?coords . \n     \n     # That are in a circle with a centre of with a point\n     bd:serviceParam wikibase:center "Point(3.43,50.45)"^^geo:wktLiteral   . \n     # Where the circle has a radius of 20km\n     bd:serviceParam wikibase:radius "20" . \n     bd:serviceParam wikibase:distance ?distance .\n   } .\n\n   ?qid wdt:P31/wdt:P279* wd:Q486972.\n\n   # Use the label service to get the English label\n   SERVICE wikibase:label {\n   bd:serviceParam wikibase:language "en" . \n   }\n}\nORDER BY ?distance'

# %%
applique_requete(req, prefixes, headers)
# Out:
# [{'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '0.103'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2820650'},
#   'qidLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Abbaye de Notre-Dame-de-la-Paix'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.42861111 50.44972222)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '0.103'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q334131'},
#   'qidLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Saint-Amand Abbey'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.42861111 50.44972222)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '0.208'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3551133'},
#   'qidLabel': {'type': 'literal', 'value': 'Q3551133'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.42806 50.4486)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '0.306'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q626309'},
#   'qidLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Saint-Amand-les-Eaux'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.426944444 50.448055555)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '3.205'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q654369'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Millonfosse'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.390833333 50.435555555)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '3.421'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1164809'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lecelles'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.394444444 50.470833333)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '3.633'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1165059'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nivelle'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.467222222 50.4725)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '3.912'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q740734'},
#   'qidLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Thun-Saint-Amand'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.458888888 50.48)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '4.443'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q728757'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hasnon'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.386666666 50.421111111)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value':
'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.396'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q947212'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quevaucamps'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.68333333 50.51666667)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.413'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q732623'},
#   'qidLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Cappelle-en-Pévèle'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.1725 50.510277777)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.441'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3039070'},
#   'qidLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Montrœul-sur-Haine'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.703666 50.436001)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.48'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q817366'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sebourg'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.646666666 50.342222222)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.48'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q114360372'},
#   'qidLabel': {'type': 'literal', 'value': 'Q114360372'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.646666666 50.342222222)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.558'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q665525'},
#   'qidLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Montigny-en-Ostrevent'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.186944444 50.366666666)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.638'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2577974'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hertain'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.28333333 50.6)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.701'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2010088'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Froyennes'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.3547 50.6206)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.704'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q737269'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Émerchicourt'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.253611111 50.313055555)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.717'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2394203'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Béclers'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.5033 50.6211)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.72'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1099211'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lallaing'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.168055555 50.39)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.723'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1099426'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Masny'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.201666666 50.348611111)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.783'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q35733032'},
#   'qidLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Montigny-en-Ostrevent'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.18333 50.36667)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.87'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q333880'},
#   'qidLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Abbaye de Cysoing'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.2144722 50.5646611)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.952'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1160662'},
#   'qidLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Templeuve-en-Pévèle'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.175 50.526666666)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.952'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q86675474'},
#   'qidLabel': {'type': 'literal', 'value': 'Q86675474'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.175 50.526666666)'}},
#  {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#    'type': 'literal',
#    'value': '19.971'},
#   'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1116258'},
#   'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Anhiers'},
#   'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#    'type': 'literal',
#    'value': 'Point(3.156388888 50.406666666)'}}]

# %% [markdown]
# ## Élimination d'en-tête verbeux
# Les en-têtes sont verbeux. On les nettoie.

# %%
def condense_dict(dico: dict) -> dict:
    nouv_dict = dict()
    for key in dico.keys():
        if type(dico[key]) == dict and 'value' in dico[key]:
            nouv_dict[key] = dico[key]['value']
        else:
            nouv_dict[key] = dico[key]
    return nouv_dict

# %%
def deduplique(dicos: list[dict]) -> dict:
    nouv_dict = dict()
    for dico in dicos:
        for key in dico.keys():
            if key in nouv_dict:
                nouv_dict[key] += [dico[key]]
            else:
                nouv_dict[key] = [dico[key]]
    for key in nouv_dict.keys():
        nouv_dict[key] = set(nouv_dict[key])
    for key in nouv_dict.keys():
        vals = []
        for val in nouv_dict[key]:
            if val.startswith('http://www.wikidata.org/entity/'):
                vals += [val[len('http://www.wikidata.org/entity/'):]]
            else:
                vals += [val]
        nouv_dict[key] = vals
    return nouv_dict

# %%
def creer_nuplet(dicts_cond: list[dict]):
    nuplets = []
    for dict_cond in dicts_cond:
        if dict_cond['qid'].startswith('http://www.wikidata.org/entity/'):
                dict_cond['qid'] = [dict_cond['qid'][len('http://www.wikidata.org/entity/'):]]
        nuplet = (dict_cond['distance'],
                dict_cond['qid'][0],
                dict_cond['qidLabel'],
                dict_cond['coords'])
        nuplets += [nuplet]
    return nuplets

# %%
def fusionne_dicts_wd(dicts_wd: list) -> dict:
    print(dicts_wd)
    dicts_cond = [condense_dict(dict_wd)
                  for dict_wd in dicts_wd]
    nouv_dict = creer_nuplet(dicts_cond)
    return nouv_dict

# %% [markdown]
# ## Application de la requête
# Maintenant on extrait les candidats avec la requête. On prend _Molina_ comme exemple et on limite les candidats par un rayon maximal, ici 20 km fixé en dur dans la requête SPARQL.

# %%
def extrait_serveur_wd(qt: str):
    data = requests.get(url, params={
                        'query': prefixes + qt, 'format': 'json', 'headers': headers}).json()
    #print(data)
    cond_data = fusionne_dicts_wd(data['results']['bindings'])
    return cond_data

# %%
req = cree_req_coord('Point(-1.7461111111111105,40.833333333333336)')
req
# Out:
# 'SELECT DISTINCT ?distance ?qid ?qidLabel ?coords WHERE {\n\n   # Use the around service\n   SERVICE wikibase:around { \n     # Looking for items with coordinate locations(P625)\n     ?qid wdt:P625 ?coords . \n     \n     # That are in a circle with a centre of with a point\n     bd:serviceParam wikibase:center "Point(-1.7461111111111105,40.833333333333336)"^^geo:wktLiteral   . \n     # Where the circle has a radius of 20km\n     bd:serviceParam wikibase:radius "20" . \n     bd:serviceParam wikibase:distance ?distance .\n   } .\n\n   ?qid wdt:P31/wdt:P279* wd:Q486972.\n\n   # Use the label service to get the English label\n   SERVICE wikibase:label {\n   bd:serviceParam wikibase:language "en" . \n   }\n}\nORDER BY ?distance'

# %%
candidats = extrait_serveur_wd(req)
# Out:
# [{'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double', 'type': 'literal', 'value': '1.959'}, 'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1656043'}, 'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Castellar de la Muela'}, 'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-1.759444444 40.818888888)'}}, {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double', 'type': 'literal', 'value': '4.284'}, 'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q6149117'}, 'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tordelpalo'}, 'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-1.7963 40.826816666)'}}, {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double', 'type': 'literal', 'value': '4.465'}, 'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q118092717'}, 'qidLabel': {'type': 'literal', 'value': 'Q118092717'}, 'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-1.7857 40.8066)'}}, {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double', 'type': 'literal', 'value': '5.07'}, 'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q5765761'}, 'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chera, Guadalajara'}, 'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-1.771388888 40.791944444)'}}, {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double', 'type': 'literal', 'value': '5.402'}, 'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q54801224'}, 'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Anchuela del Pedregal'}, 'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-1.808972222 40.843280555)'}}, {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double', 'type': 'literal', 'value': '6.169'}, 'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1654736'}, 'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Morenilla'}, 'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-1.7076042 40.7861279)'}}, {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double', 'type': 'literal', 'value': '6.225'}, 'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q534562'}, 'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hombrados'}, 'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-1.6853606 40.8013884)'}}, {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double', 'type': 'literal', 'value': '6.266'}, 'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30317286'}, 'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cubillejo de la Sierra'}, 'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-1.774472222 40.885444444)'}}, {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double', 'type': 'literal', 'value': '6.677'}, 'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q24011113'}, 'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Prados Redondos'}, 'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-1.79329 40.78505)'}}, {'distance': {'datatype': 'http://www.w3.org/2001/XMLSchema#double', 'type': 'literal', 'value': '6.72'}, 'qid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1656490'}, 'qidLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Prados Redondos'}, 'coords': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-1.7935166 40.7847021)'}}, {'distance': {'datatype': 'htt ...

# %%
for i, candidat in enumerate(candidats):
    if 'Molina' in candidat[2]:
        print('->', i, candidat)
    else:
        print(i, candidat)
# Out:
# 0 ('1.959', 'Q1656043', 'Castellar de la Muela', 'Point(-1.759444444 40.818888888)')
# 1 ('4.284', 'Q6149117', 'Tordelpalo', 'Point(-1.7963 40.826816666)')
# 2 ('4.465', 'Q118092717', 'Q118092717', 'Point(-1.7857 40.8066)')
# 3 ('5.07', 'Q5765761', 'Chera, Guadalajara', 'Point(-1.771388888 40.791944444)')
# 4 ('5.402', 'Q54801224', 'Anchuela del Pedregal', 'Point(-1.808972222 40.843280555)')
# 5 ('6.169', 'Q1654736', 'Morenilla', 'Point(-1.7076042 40.7861279)')
# 6 ('6.225', 'Q534562', 'Hombrados', 'Point(-1.6853606 40.8013884)')
# 7 ('6.266', 'Q30317286', 'Cubillejo de la Sierra', 'Point(-1.774472222 40.885444444)')
# 8 ('6.677', 'Q24011113', 'Prados Redondos', 'Point(-1.79329 40.78505)')
# 9 ('6.72', 'Q1656490', 'Prados Redondos', 'Point(-1.7935166 40.7847021)')
# 10 ('7.603', 'Q24011243', 'Campillo de Dueñas', 'Point(-1.68505 40.88376)')
# 11 ('7.786', 'Q1655088', 'Campillo de Dueñas', 'Point(-1.683611111 40.885)')
# 12 ('8.018', 'Q21003995', 'Cubillejo del Sitio', 'Point(-1.803694444 40.890805555)')
# 13 ('8.413', 'Q118094057', 'Q118094057', 'Point(-1.8295 40.7916)')
# 14 ('8.585', 'Q54687134', 'Novella', 'Point(-1.847763888 40.84015)')
# 15 ('9.487', 'Q1654884', 'Castilnuevo', 'Point(-1.856388888 40.815555555)')
# 16 ('9.923', 'Q634254', 'Anquela del Pedregal', 'Point(-1.735555555 40.744444444)')
# 17 ('10.266', 'Q24011118', 'Q24011118', 'Point(-1.64979 40.77669)')
# 18 ('10.282', 'Q1654744', 'El Pobo de Dueñas', 'Point(-1.6500158 40.7762278)')
# 19 ('10.428', 'Q1653703', 'La Yunta', 'Point(-1.6833548 40.9142317)')
# -> 20 ('10.597', 'Q1750989', 'Torrecuadrada de Molina', 'Point(-1.8066344 40.7497637)')
# 21 ('10.929', 'Q6054525', 'Q6054525', 'Point(-1.783333333 40.739166666)')
# 22 ('10.991', 'Q1656880', 'Torremochuela', 'Point(-1.841389 40.7657327)')
# -> 23 ('11.695', 'Q24011146', 'Molina de Aragón', 'Point(-1.884669444 40.841880555)')
# -> 24 ('12.045', 'Q919050', 'Molina de Aragón', 'Point(-1.888611111 40.843888888)')
# 25 ('12.045', 'Q43167339', 'Q43167339', 'Point(-1.888611 40.843889)')
# 26 ('12.191', 'Q15303691', 'Monastery of Saint Francis', 'Point(-1.890552777 40.842225)')
# 27 ('12.712', 'Q24011030', 'Q24011030', 'Point(-1.66405 40.92936)')
# 28 ('13.08', 'Q1655596', 'Rueda de la Sierra', 'Point(-1.8536762 40.9183294)')
# 29 ('13.818', 'Q55974138', 'Valsalobre', 'Point(-1.909311111 40.819383333)')
# 30 ('14.018', 'Q584623', 'Tordellego', 'Point(-1.6702474 40.7211139)')
# 31 ('14.087', 'Q55978683', 'Castellote', 'Point(-1.913383333 40.839280555)')
# 32 ('14.79', 'Q21065615', 'Cillas', 'Point(-1.847355555 40.942116666)')
# 33 ('15.47', 'Q24011089', 'Setiles', 'Point(-1.6172 40.73419)')
# 34 ('15.547', 'Q1655922', 'Setiles', 'Point(-1.616666666 40.733611111)')
# 35 ('15.816', 'Q1654380', 'Embid', 'Point(-1.710833333 40.973055555)')
# 36 ('15.917', 'Q1653693', 'El Pedregal', 'Point(-1.5708608 40.7795239)')
# 37 ('15.966', 'Q24011128', 'Q24011128', 'Point(-1.57033 40.77934)')
# 38 ('15.995', 'Q24011064', 'Tortuera', 'Point(-1.79764 40.97181)')
# 39 ('16.005', 'Q1768496', 'Odón', 'Point(-1.5681704 40.8843906)')
# 40 ('16.016', 'Q23994081', 'Odón', 'Point(-1.56792 40.88417)')
# 41 ('16.112', 'Q1656964', 'Tortuera', 'Point(-1.796944444 40.973055555)')
# 42 ('16.418', 'Q1655891', 'Rillo de Gallo', 'Point(-1.936111111 40.867222222)')
# 43 ('16.935', 'Q55978752', 'Cañizares', 'Point(-1.947088888 40.842191666)')
# 44 ('17.018', 'Q55769025', 'Terraza', 'Point(-1.947908333 40.822825)')
# 45 ('17.13', 'Q55974089', 'Teroleja', 'Point(-1.945380555 40.801811111)')
# 46 ('18.12', 'Q593530', 'Tierzo', 'Point(-1.9304979 40.7492491)')
# 47 ('18.412', 'Q621708', 'Adobes', 'Point(-1.678611111 40.675833333)')
# 48 ('18.755', 'Q55975146', 'Ventosa', 'Point(-1.968763888 40.824983333)')
# 49 ('18.855', 'Q108282687', 'Valhermoso', 'Point(-1.96121 40.7859)')
# 50 ('18.929', 'Q1769433', 'Herrería', 'Point(-1.958888888 40.888888888)')
# 51 ('18.994', 'Q541954', 'Piqueras', 'Point(-1.720555555 40.663611111)')
# 52 ('19.071', 'Q1656870', 'Traíd', 'Point(-1.8094698 40.6686635)')
# 53 ('19.13', 'Q63105189', 'Traid', 'Point(-1.80971 40.66817)')
# 54 ('19.385', 'Q1750974', 'Valhermoso', 'Point(-1.966666666 40.783055555)')
# 55 ('19.428', 'Q5821349', 'Archaeological site of El Ceremeño', 'Point(-1.96611111 40.88666667)')
# 56 ('19.571', 'Q24011219', 'Corduente', 'Point(-1.97841 40.84304)')
# 57 ('19.612', 'Q1656843', 'Torrubia', 'Point(-1.9003844 40.9656772)')
# 58 ('19.613', 'Q1653755', 'Corduente', 'Point(-1.978888888 40.843333333)')
# 59 ('19.725', 'Q2000595', 'Pardos', 'Point(-1.924166666 40.948888888)')
# 60 ('19.727', 'Q115626721', 'Terzaguilla', 'Point(-1.928 40.7215)')
# 61 ('19.772', 'Q126038099', 'Q126038099', 'Point(-1.9452 40.739)')
# 62 ('19.963', 'Q126038281', 'Salinas de Armallá', 'Point(-1.9451 40.7357)')
